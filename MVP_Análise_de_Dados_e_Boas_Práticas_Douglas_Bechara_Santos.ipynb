# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasbechara/Notebooks/blob/main/MVP_An%C3%A1lise_de_Dados_e_Boas_Pr%C3%A1ticas_Douglas_Bechara_Santos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MVP da Sprint: Análise de dados e boas práticas**
# Aluno: Douglas Bechara Santos

# %% [markdown]
# # **1. Definição do problema**

# %% [markdown]
# * Descrição do problema?
# O problema refere-se a ....
#
# * O problema é classificado como aprendizado supervisionado ou não supervisionado?
#
# * Premissas ou hipóteses sobre o problema?
#   * Premissas:
#     * Dados sensíveis dos alunos, não podem ser identificados.
#     *
#
#   * Hipóteses:
#     * A
#     * A
#
# 1.4 Restrições ou condições impostas para selecionar os dados?
#
# 1.5 Defição de cada um dos atributos do dataset.
#
# Possui objetivo de realizar análises em um Data Frame de dados escolares de alunos de um curso Técnico em Informática Integrado ao Ensino Médio, retirado do Sistema Integrado de Atividades Acadêmicas - SIGAA de uma instituição educacional.
#
# O Data Frame apresentado é trabalhado com dados tabulares que pode ser entendido como uma tabela que organiza os dados em linhas e colunas, criando uma estrutura de dados bidimensional e que classificamos como aprendizado supervisionado, pois os dados do Data Frame em questão possuem variáveis *target*, ou seja, nossas variáveis de interesse no conjunto de dados em questão, com isso abrimos a possibilidade de prever resultados finais
#
# As análises consitirão em verificar o histórico de cada aluno para:
# * Entender quais as principais disciplinas que necessitam de reforço;
# * Quais alunos precisam de maior atenção na relação ensino aprendizado e quais possuem maior ausência em sala de aula;
#
# Diante a resposta dessas perguntas, poderemos propor possíveis soluções para cada questionamento levantado, para isso, realizaremos estudos .... onde será necessário ....
#
# Sabemos que Data Frame possui os seguintes atributos:
# * Matrícula
# * Aluno(a)
# * Código
# * Disciplinas
# * 1º Bimestre
# * 2º Bimestre
# * 3º Bimestre
# * 4º Bimestre
# * Recuperação
# * Média final
# * Resultado
# * Faltas
# * Situação

# %% [markdown]
# # **Acessando os dados do Google Sheets**

# %% [markdown]
# Instalar um **pacote Gspread** que não é padrão do Colab.
#
# `pip install --upgrade gspread`
#
# Anatomia do comando para iniciantes:
# * `pip` É um gerenciador de pacotes no Python, então ele vai gerenciar as bibliotecas que você vai instalar, desinstalar e atualizar. [Fonte](https://www.hashtagtreinamentos.com/pip-install-no-python#:~:text=dentro%20do%20Python.-,Pip%20no%20Python,que%20voc%C3%AA%20j%C3%A1%20possa%20utilizar.)
#
# * `install` Comando de instalação.
#
# * `-- upgrade` Para garantir que a versão instalada seja pelo menos tão recente quanto a disponível. [Fonte](https://docs.python.org/pt-br/3/library/ensurepip.html?highlight=upgrade)
#
# * `gsdpread` É uma API Python para Planilhas Google. [Fonte](https://docs.gspread.org/en/latest/)

# %%
#pip install --upgrade gspread

# %% [markdown]
# 2.2 Autenticação no Google Sheet. [Fonte](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=6d0xJz3VzLOo)

# %%
# from google.colab import auth
# auth.authenticate_user()

# import gspread
# from google.auth import default
# creds, _ = default()

# gc = gspread.authorize(creds)

# %% [markdown]
# 2.3 Criando variável para acessar a planilha do Google Sheet
# `MVP_notas_alunos = gc.open('Controle_de_notas_T229-MJ')`

# %%
# MVP_notas_alunos = gc.open('Controle_de_notas_T229-MJ')

# %%
# aba1 = MVP_notas_alunos.sheet1

# %%
# aba1.row_values(2)

# %% [markdown]
# 2... Instalando a *biblioteca Matplotlib* para criação de gráficos e visualizações de dados em geral. Isso facilitará nossa visualização dos dados dento do Colab.

# %%
# pip install matplotlib

# %% [markdown]
# # **2. Importação de bibliotecas**

# %%
# Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import cm
import missingno as ms

# %% [markdown]
# # **3. Coletando dados do Github**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/douglasbechara/MVP-Analise-de-Dados-e-Boas-Praticas/main/Controle_de_notas.csv")

# %% [markdown]
# # **4. Análise dos dados**

# %% [markdown]
# ## 4.1 Compreensão do Data Frame

# %% [markdown]
# ### Visão geral

# %%
# Observar o tamanho do dataset que possui 561 linhas e 13 colunas.
df.shape
# Out:
# (561, 13)

# %% [markdown]
# O Data Frame possui 561 linhas e 13 colunas

# %%
# Visualização das primeiras linhas do Data Frame
df.head()
# Out:
#   Ano letivo de 2023                     Unnamed: 1 Unnamed: 2  \
# 0          Matrícula                       Aluno(a)     Código
# 1        20232294062  ALANY GABRIELY DOS REIS GOMES  TIINF1409
# 2                NaN                            NaN  TIINF1398
# 3                NaN                            NaN  TIINF1405
# 4                NaN                            NaN  TIINF1397
#
#                              Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0                           Disciplinas  1º Bimestre  2º Bimestre
# 1  ALGORITMO E LINGUAGEM DE PROGRAMAÇÃO         8,25         8,13
# 2                        ARTES E MÚSICA        10,00        10,00
# 3                            BIOLOGIA I         9,30         8,80
# 4                     EDUCAÇÃO FÍSICA I         7,00         7,00
#
#     Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9   Unnamed: 10  \
# 0  3º Bimestre  4º Bimestre  Recuperação  Média final     Resultado
# 1         7,50          NaN          NaN         2,99  Reprovado(a)
# 2         9,00          NaN          NaN         7,25   Aprovado(a)
# 3         7,00          NaN          NaN         3,14  Reprovado(a)
# 4          NaN          NaN          NaN         1,75  Reprovado(a)
#
#   Unnamed: 11  Unnamed: 12
# 0      Faltas     Situação
# 1           0  MATRICULADO
# 2           0  MATRICULADO
# 3           1  MATRICULADO
# 4           0  MATRICULADO

# %%
# Visualiza as últimas linhas
# Últimas inserções de valores no Data Frame
df.tail()
# Out:
#     Ano letivo de 2023 Unnamed: 1 Unnamed: 2             Unnamed: 3  \
# 556                NaN        NaN  TIINF1395    LÍNGUA PORTUGUESA I
# 557                NaN        NaN  TIINF1406           MATEMÁTICA I
# 558                NaN        NaN  TIINF1403              QUÍMICA I
# 559                NaN        NaN  TIINF1410  SISTEMAS OPERACIONAIS
# 560                NaN        NaN  TIINF1401           SOCIOLOGIA I
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 556       8,00       8,00        NaN        NaN        NaN       2,00
# 557       9,00       7,20       9,30        NaN        NaN       3,19
# 558       9,00      10,00       9,00        NaN        NaN       3,50
# 559       9,50       8,00       8,50        NaN        NaN       3,25
# 560       7,50       7,70       9,00        NaN        NaN       3,03
#
#       Unnamed: 10 Unnamed: 11 Unnamed: 12
# 556  Reprovado(a)           2         NaN
# 557  Reprovado(a)           0         NaN
# 558  Reprovado(a)           0         NaN
# 559  Reprovado(a)           0         NaN
# 560  Reprovado(a)           0         NaN

# %%
# Pegar uma amostra das linhas para visualização
df.sample(10)
# Out:
#     Ano letivo de 2023                        Unnamed: 1 Unnamed: 2  \
# 346                NaN                               NaN  TIINF1408
# 289        20232294116  JOYCE VITÓRIA GONÇALVES DO MONTE  TIINF1409
# 226                NaN                               NaN  TIINF1398
# 96                 NaN                               NaN  TIINF1401
# 466                NaN                               NaN  TIINF1398
# 442                NaN                               NaN  TIINF1408
# 170                NaN                               NaN  TIINF1408
# 354                NaN                               NaN  TIINF1398
# 22                 NaN                               NaN  TIINF1404
# 287                NaN                               NaN  TIINF1410
#
#                                Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 346                   INTRODUÇÃO À LÓGICA       9,70       9,50        NaN
# 289  ALGORITMO E LINGUAGEM DE PROGRAMAÇÃO       8,30       7,42       8,10
# 226                        ARTES E MÚSICA      10,00      10,00       9,00
# 96                           SOCIOLOGIA I       7,60       8,30       9,10
# 466                        ARTES E MÚSICA      10,00      10,00       9,00
# 442                   INTRODUÇÃO À LÓGICA       7,50       6,50        NaN
# 170                   INTRODUÇÃO À LÓGICA       7,50       5,50        NaN
# 354                        ARTES E MÚSICA       8,00       9,00       9,50
# 22                               FÍSICA I       8,30       7,00       7,00
# 287                 SISTEMAS OPERACIONAIS       6,50       9,00       8,00
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9   Unnamed: 10 Unnamed: 11 Unnamed: 12
# 346        NaN        NaN       2,40  Reprovado(a)           0         NaN
# 289        NaN        NaN       2,98  Reprovado(a)         NaN         NaN
# 226        NaN        NaN       7,25   Aprovado(a)         NaN         NaN
# 96         NaN        NaN       3,13  Reprovado(a)         NaN         NaN
# 466        NaN        NaN       7,25   Aprovado(a)           0         NaN
# 442        NaN        NaN       1,75  Reprovado(a)           0         NaN
# 170        NaN        NaN       1,63  Reprovado(a)         NaN         NaN
# 354        NaN        NaN       3,31  Reprovado(a)           0         NaN
# 22         NaN        NaN       2,79  Reprovado(a)         NaN         NaN
# 287        NaN        NaN       2,94  Reprovado(a)         NaN         NaN

# %%
# Apresenta, de forma resumida, quais os tipos de variáveis
df.dtypes
# Out:
# Ano letivo de 2023    object
# Unnamed: 1            object
# Unnamed: 2            object
# Unnamed: 3            object
# Unnamed: 4            object
# Unnamed: 5            object
# Unnamed: 6            object
# Unnamed: 7            object
# Unnamed: 8            object
# Unnamed: 9            object
# Unnamed: 10           object
# Unnamed: 11           object
# Unnamed: 12           object
# dtype: object

# %%
# Informações do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ano letivo de 2023  36 non-null     object
#  1   Unnamed: 1          36 non-null     object
#  2   Unnamed: 2          561 non-null    object
#  3   Unnamed: 3          561 non-null    object
#  4   Unnamed: 4          558 non-null    object
#  5   Unnamed: 5          552 non-null    object
#  6   Unnamed: 6          410 non-null    object
#  7   Unnamed: 7          39 non-null     object
#  8   Unnamed: 8          2 non-null      object
#  9   Unnamed: 9          561 non-null    object
#  10  Unnamed: 10         561 non-null    object
#  11  Unnamed: 11         273 non-null    object
#  12  Unnamed: 12         17 non-null     object
# dtypes: object(13)
# memory usage: 57.1+ KB

# %%
# Estatíticas descritivas do dataset
df.describe()
# Out:
#        Ano letivo de 2023 Unnamed: 1 Unnamed: 2                 Unnamed: 3  \
# count                  36         36        561                        561
# unique                 36         36         17                         17
# top             Matrícula   Aluno(a)  TIINF1402  GEOGRAFIA E MEIO AMBIENTE
# freq                    1          1         35                         35
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# count         558        552        410         39            2        561
# unique         78         70         67          4            2        176
# top         10,00      10,00      10,00      10,00  Recuperação       0,00
# freq          111         85         80         32            1         30
#
#          Unnamed: 10 Unnamed: 11  Unnamed: 12
# count            561         273           17
# unique             3           8            2
# top     Reprovado(a)           0  MATRICULADO
# freq             441         217           16

# %%
# Resumo estatístico das variáveis que interessam
df.iloc[:,5:].describe()
# Out:
#        Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8 Unnamed: 9   Unnamed: 10  \
# count         552        410         39            2        561           561
# unique         70         67          4            2        176             3
# top         10,00      10,00      10,00  Recuperação       0,00  Reprovado(a)
# freq           85         80         32            1         30           441
#
#        Unnamed: 11  Unnamed: 12
# count          273           17
# unique           8            2
# top              0  MATRICULADO
# freq           217           16

# %% [markdown]
# ### Há valores faltantes?

# %%
# Apresenta quantos dados faltantes
df.isna().sum()
# Out:
# Ano letivo de 2023    525
# Unnamed: 1            525
# Unnamed: 2              0
# Unnamed: 3              0
# Unnamed: 4              3
# Unnamed: 5              9
# Unnamed: 6            151
# Unnamed: 7            522
# Unnamed: 8            559
# Unnamed: 9              0
# Unnamed: 10             0
# Unnamed: 11           288
# Unnamed: 12           544
# dtype: int64

# %%
# Caso tenha dados faltantes, podemos tirar as linhas
# df = df.dropna()

# %% [markdown]
# ### Número de valores únicos no Data Frame para cada coluna

# %%
df.nunique()

# %%
# Ocorrências únicas
# Vídeo: Time_9:54
df.['Unnamed:'].unique()

# %% [markdown]
# ### Análise de uma colega

# %%
# Correlação pelo método Person
df.corr(method='pearson')

# %%
# Histograma para cada atributo
df.hist(figsize=(40,20))
plt.show()

# %%
# Densidade de cada atribuito
f=df.plot(kind="box",subplots=True, layout=(5,5), share=False, figsize=(30,10))
plt.show()

# %%
# Densidade Plot de cada atribuito
df.plot(king="box", subplots=True, layout=(5,5), sharex=False, figsize=(30,20))
plt.show()

# %%
# Gráfico de Correlação
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(), annot=True, cmap='RdBu', vmin=0, vmax=10);

# %% [markdown]
# # **5. Pré-processamento dos dados**

# %% [markdown]
# ### Substituição de eventos por outros nomes

# %%
# df['Ano letivo de 2023'].replace({'0':'nenhum',})

# %% [markdown]
# Para melhorar a visualização dos "eventos" e vamos substituir por outros nomes.
# Obs: *inplace=True* faz com que a modificação seja feita e salva no Data Frame.

# %% [markdown]
# ### Novo subtópico

# %%
#

# %% [markdown]
# Explicação

# %% [markdown]
# ### Há dados duplicados?

# %%
# Retiramos dados duplicados em relação a todas as variáveis
# df.loc[df.duplicated()]

# %%
# Retiramos dados duplicados em relação a um conjunto específico de variáveis
df.loc[df.duplicated(subset=['Ano letivo de 2023'])]

# %%
# Valores missing
df.isnull().sum()

# %% [markdown]
# ### Relação entre variáveis
#
# * Diagramas de dispersão
# * Mapas de calor (*heatmaps*)
# * Agrupamento de dados: *groupby*(depois)

# %%
# Visualizar as colunas do Data Frame
df.columns
# Out:
# Index(['Ano letivo de 2023', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
# Correlação entre variáveis
# Importante observar que a correção entre variáveis ocorre com dados númericos
df.iloc[5:,7:].corr(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# heatmap sem opções
sns.heatmap(df.corr(),annot=True)

# %%
#
# Necessário retirar dados nulos do Data Frame
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(numeric_only=True),cmap='BrBG',annot=True);

# %% [markdown]
# ### Diagrama de dispersão

# %%
df.plot(king='scatter', )

# %% [markdown]
# # **6. Tratamento dos dados**

# %% [markdown]
# ### Matriz de distribuição dos missings do Data Frame

# %% [markdown]
# # **7. Descrição do MVP**

# %% [markdown]
# 3.   **Análise de dados**
# ---
# Estatísticas descritivas:
# * Quantos atributos e instâncias existem?
#
# * Quais são os tipos de dados dos atributos?
#
# * Verifique as primeiras linhas do dataset. Algo chama a atenção?
#
# * Há valores faltantes, discrepantes ou inconsistentes?
#
# * Faça um resumo estatístico dos atributos com valor numérico (mínimo, máximo, mediana, moda, média, desvio-padrão e número de valores ausentes). O que você percebe?
#
# ---
# Visualizações:
#
# * Verifique a distribuição de cada atributo. O que você percebe? Dica: esta etapa pode dar ideias sobre a necessidade de transformações na etapa de preparação de dados (por exemplo, converter atributos de um tipo para outro, realizar operações de discretização, normalização, padronização, etc.).
#
# * Se for um problema de classificação, verifique a distribuição de frequência das classes. O que você percebe? Dica: esta etapa pode indicar a possível necessidade futura de balanceamento de classes.
#
# * Analise os atributos individualmente ou de forma combinada, usando os gráficos mais apropriados.

# %% [markdown]
# 3. **Pré-processamento de dados**
#
# * Verifique quais operações de pré-processamento podem ser interessantes para o seu problema e salve visões diferentes do seu dataset (por exemplo, normalização, padronização, discretização e one-hot-encoding).
#
# * Trate (removendo ou substituindo) os valores faltantes (se existentes).
# Realize outras transformações de dados porventura necessárias.
#
# * Explique, passo a passo, as operações realizadas, justificando cada uma delas.
#
# * Se julgar necessário, utilizando os dados pré-processados, volte na etapa de análise exploratória e verifique se surge algum insight diferente após as operações realizadas.
